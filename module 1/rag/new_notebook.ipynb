# %%
from sqlitesearch import TextSearchIndex
import os
from rag_helper import RAGBase
from openai import OpenAI

# %%
sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
sqlite_index.count()
# Out:
# 106

# %%
results = sqlite_index.search("Can I still join the course after it started?", num_results=5)
[doc["question"] for doc in results]
# Out:
# ['I just discovered the course. Can I still join?',
#  'I just discovered the course. Can I still join?',
#  'I just discovered the course. Can I still join?',
#  'I just discovered the course. Can I still join?',
#  'How do I start using Google Gemini models in the Module 1 notebook through the OpenAI-compatible endpoint?']

# %%
api_key=os.environ["PERPLEXITY_API_KEY"]
base_url="https://api.perplexity.ai"

# %%
openai_client = OpenAI(api_key=api_key, base_url=base_url)

# %%
assistant = RAGBase(
    index=sqlite_index,
    llm_client=openai_client,
)

# %%
answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# Yes, you can join the course now[General Course-Related Questions]. However, if you want to receive a certificate, you must submit your project while submissions are still being accepted[General Course-Related Questions].
#
# You do not need to wait for a confirmation email to start—you are already accepted and can begin learning and submitting homework immediately while the form is open[General Course-Related Questions]. Registration is only used to gauge interest before the course start date and is not checked against a registered list[General Course-Related Questions].

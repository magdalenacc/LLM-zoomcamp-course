# %%
from dotenv import load_dotenv
load_dotenv()

from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from openai import OpenAI
import os

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
api_key=os.environ["PERPLEXITY_API_KEY"]
base_url="https://api.perplexity.ai"

# %%
openai_client = OpenAI(api_key=api_key, base_url=base_url)

# %%
assistant = RAGBase(
    index=index,
    llm_client=openai_client,
)

# %%
answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# Yes, you can join the course now.
#
# However, if you want to receive a **certificate**, you must **submit your project** while the course is still **accepting submissions** [Context]. You do not need a confirmation email to start; you are already accepted and can begin learning and submitting homework immediately while the form is open [Context]. The course materials (videos and GitHub content) are available, and you can start whenever you want [Context].
#
# Note: Certificates are only awarded if you complete the course with a **live cohort**; self-paced completion does not result in a certificate because peer reviews of projects are only conducted during the live course period [Context].
